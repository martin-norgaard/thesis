# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_stata("http://macrohistory.net/JST/JSTdatasetR4.dta", index_col="year")

# %%
#df.head()
df.iso.unique()
# Out:
# array(['AUS', 'BEL', 'CAN', 'DNK', 'FIN', 'FRA', 'DEU', 'ITA', 'JPN',
#        'NLD', 'NOR', 'PRT', 'ESP', 'SWE', 'CHE', 'GBR', 'USA'],
#       dtype=object)

# %%
df_uk = df[df.iso == "GBR"]
df_uk.head()
# Out:
#        country  iso  ifs      pop      rgdpmad     rgdppc  rconpc       gdp  \
# year
# 1870.0      UK  GBR  112  31400.0  3190.434013  13.815308   14.81  1.056202
# 1871.0      UK  GBR  112  31685.0  3331.875020  14.210668   15.24  1.141664
# 1872.0      UK  GBR  112  31874.0  3319.165401  14.156267   15.35  1.211361
# 1873.0      UK  GBR  112  32177.0  3364.697641  14.474454   15.55  1.270045
# 1874.0      UK  GBR  112  32501.0  3386.444109  14.418424   15.93  1.262897
#
#               iy       cpi  ...  eq_capgain     eq_dp  eq_capgain_interp  \
# year                        ...
# 1870.0  0.074343  2.197213  ...         NaN       NaN                NaN
# 1871.0  0.078265  2.227974  ...      0.2002  0.051408                NaN
# 1872.0  0.087918  2.332689  ...      0.0328  0.029338                NaN
# 1873.0  0.088830  2.405002  ...      0.0196  0.029521                NaN
# 1874.0  0.100768  2.325637  ...     -0.0120  0.044231                NaN
#
# ...

# %% [markdown]
# Find documentation for variable names here: http://www.macrohistory.net/JST/JSTdocumentationR4.pdf

# %%
df_uk_focus = df[['country', 'iso', 'pop', 'gdp', 'iy', 'cpi','safe_tr','bill_rate','risky_tr','eq_dp','eq_div_rtn']]

# %%
df_uk_focus.head()
# Out:
#           country  iso     pop     gdp        iy       cpi  safe_tr  \
# year
# 1870.0  Australia  AUS  1775.0  208.78  0.109266  2.708333      NaN
# 1871.0  Australia  AUS  1675.0  211.56  0.104579  2.666667      NaN
# 1872.0  Australia  AUS  1722.0  227.40  0.130438  2.541667      NaN
# 1873.0  Australia  AUS  1769.0  266.54  0.124986  2.541667      NaN
# 1874.0  Australia  AUS  1822.0  287.58  0.141960  2.666667      NaN
#
#         bill_rate  risky_tr     eq_dp  eq_div_rtn
# year
# 1870.0     0.0488       NaN  0.071417    0.066415
# 1871.0     0.0460       NaN  0.065466    0.068193
# 1872.0     0.0460       NaN  0.062997    0.069861
# 1873.0     0.0440       NaN  0.064484    0.069842
# 1874.0     0.0450       NaN  0.063503    0.071085

# %%
plt.figure()
plt.subplot(111)
plt.bar(df_uk_focus.index, df_uk_focus.safe_tr, 
         df_uk_focus.risky_tr)
plt.subplot(112)
plt.bar(df_uk_focus.index, df_uk_focus.cpi)
plt.show
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-1a7bc798daf3> in <module>
#       3 plt.bar(df_uk_focus.index, df_uk_focus.safe_tr,
#       4          df_uk_focus.risky_tr)
# ----> 5 plt.subplot(112)
#       6 plt.bar(df_uk_focus.index, df_uk_focus.cpi)
#       7 plt.show
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1082
#    1083     fig = gcf()
# -> 1084     a = fig.add_subplot(*args, **kwargs)
#    1085     bbox = a.bbox
#    1086     byebye = []
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1365                     self._axstack.remove(ax)
#    1366
# -> 1367             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1368         self._axstack.add(key, a)
#    1369         self.sca(a)
#
# ...
